# %% [markdown]
# # Graphe zoomable avec Matplotlib

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Cela ne fonctionne que dans un notebook et avec la version 1.4.2+ de matploblib. Le cas classique en style [ggplot](http://matplotlib.org/users/style_sheets.html) parce que c'est plus joli :

# %%
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# On essaye avec un graphe quelconque :

# %%
import random
x = [ random.random() for i in range(0,100) ]
y = [ 2*_ + random.random()/2 for _ in x ]
ax = plt.subplot('111')
ax.plot (x,y,"o")

# %% [markdown]
# On passe à un affichage en javascript (il ne vaut mieux changer sans arrêt de cela crée quelques problèmes d'affichages). L'option n'est pas encore très stable. A suivre. Il faut redémarrer le notebook si celui-ci ne donne pas les résultats attendus.

# %%
if False:
    plt.switch_backend('nbagg')
    x = [ random.random() for i in range(0,100) ]
    y = [ 2*_ + random.random()/2 for _ in x ]
    ax = plt.subplot('111')
    ax.plot (x,y,"o")
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Pour revenir au style classique même s'il vaut mieux conserver le même style depuis le début.

# %%
plt.switch_backend('agg')  # ou %matplotlib line

# %% [markdown]
# Néanmoins, cela ne semble pas tout-à-fait au point car on ne peut pas passer d'un affichage zoomable à non zoomable comme ça. Je préfère l'aternative [mpld3](http://mpld3.github.io/) qui me paraît plus intuitive.

# %%
import mpld3
mpld3.enable_notebook()

# %%
x = [ random.random() for i in range(0,100) ]
y = [ 2*_ + random.random()/2 for _ in x ]
ax = plt.subplot('111')
ax.plot (x,y,"o")
