# %% [markdown]
# # 1A.algo - BJKST - calculer le nombre d'éléments distincts
#
# Comment calculer le nombre d'éléments distincts d'un ensemble de données quand celui-ci est trop grand pour tenir en mémoire. C'est ce que fait l'algorithme BJKST. L'extrait qui suit est tiré de
# [Counting distinct elements in a data stream](https://pdfs.semanticscholar.org/e349/7952347101a3535434bc35d378224cf87bcc.pdf) :

# %%
from pyquickhelper.helpgen import NbImage
NbImage("images/bjkst.png", width=600)

# %% [markdown]
# Saurez-vous convertir ce texte en un algorithme ?
